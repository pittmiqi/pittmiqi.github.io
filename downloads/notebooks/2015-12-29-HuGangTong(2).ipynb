# %%
# %%html
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.11.4/themes/smoothness/jquery-ui.css">
# <link href="http://www.pitt.edu/~qim3/js/keen-dashboards.css" rel ="stylesheet" type="text/css">
# <link href="https://cdnjs.cloudflare.com/ajax/libs/c3/0.4.10/c3.min.css" rel="stylesheet" type="text/css">
# <link href="https://cdnjs.cloudflare.com/ajax/libs/dc/1.7.5/dc.css" rel="stylesheet" type="text/css">
# <script src="http://www.pitt.edu/~qim3/js/jquery-ui-new.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/underscore.js/1.8.3/underscore-min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.10/d3.min.js" charset="utf-8"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/crossfilter/1.3.12/crossfilter.min.js"></script>
# <script src="http://www.pitt.edu/~qim3/js/test.js"> </script>
# <script src= "http://www.pitt.edu/~qim3/js/c3-new.js"> </script>
# <script src="http://www.pitt.edu/~qim3/js/dc-new.js"></script>
# <script src="https://code.highcharts.com/highcharts.js"></script>
# <script src="https://code.highcharts.com/modules/exporting.js"></script>
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.11.4/themes/smoothness/jquery-ui.css">
# <link href="http://www.pitt.edu/~qim3/js/keen-dashboards.css" rel ="stylesheet" type="text/css">
# <link href="https://cdnjs.cloudflare.com/ajax/libs/c3/0.4.10/c3.min.css" rel="stylesheet" type="text/css">
# <link href="https://cdnjs.cloudflare.com/ajax/libs/dc/1.7.5/dc.css" rel="stylesheet" type="text/css">
# <script src="http://www.pitt.edu/~qim3/js/jquery-ui-new.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/underscore.js/1.8.3/underscore-min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.10/d3.min.js" charset="utf-8"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/crossfilter/1.3.12/crossfilter.min.js"></script>
# <script src="http://www.pitt.edu/~qim3/js/test.js"> </script>
# <script src= "http://www.pitt.edu/~qim3/js/c3-new.js"> </script>
# <script src="http://www.pitt.edu/~qim3/js/dc-new.js"></script>
# <script src="https://code.highcharts.com/highcharts.js"></script>
# <script src="https://code.highcharts.com/modules/exporting.js"></script>

# %%
import pandas as pd
import pickle
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
import sqlite3

# Create a SQL connection to our SQLite database
con = sqlite3.connect("HGT.db")

df = pd.read_sql_query("SELECT * from hgt10", con)

#Be sure to close the connection.
con.close()

# %%
SH = df[df.市场 == '上海']
SH = SH.drop('id',1) # remove id column
SH = SH.drop_duplicates() # remove the duplicates
SH = SH.sort(columns = '日期')

# %%
## output HGT data to text file
SH_output = SH.to_json(orient='records', date_unit='s')
text_file = open("HGT_JSON.txt", "w")
text_file.write(SH_output)
text_file.close()

# %%
tail = SH.tail(50);
set(tail["名称"].values)
data_late = tail.groupby(by = ["名称"]).sum()
data_late
tail = SH.tail(100);
set(tail["名称"].values)
data_late10 = tail.groupby(by = ["名称"]).sum()
data_late
# Out:
#          收盘价   涨跌幅        净买额       买入金额       卖出金额       成交金额
# 名称
# 上海机场   92.53 -1.35 -163131088  223494282  386625370  610119652
# 上海电气   12.43  0.08  -69238068    2564235   71802303   74366538
# 上海贝岭   21.76 -0.18  -43536062    2236805   45772867   48009672
# 中信证券   80.45  3.01   20147257  206379266  186232009  392611275
# 中国太保   29.59  1.13  -82868951    2249433   85118384   87367817
# 中国平安  182.66  1.33 -445152908  206491855  651644763  858136618
# 中国建筑    6.46  0.94   30238418   35745770    5507352   41253122
# 乐凯胶片   22.11  2.46   37973176   39385285    1412109   40797394
# 亚泰集团    7.43  1.64  -82373182     709665   83082847   83792512
# 伊利股份   70.70  8.76 -695670046   94317231  789987277  884304508
# 保利地产   22.68 -6.17  -56782977   77896828  134679805  212576633
# 南方航空   17.69  2.06   39906171   73018308   33112137  106130445
# 城投控股   46.10 -9.04   11580391   68616448   57036057  125652505
# 宇通客车   22.74  4.31   35509305   72463562   36954257  109417819
# 安信信托   38.81 -0.87  183536597  191126747    7590150  198716897
# 工商银行    4.61  0.44   34193248   38855286    4662038   43517324
# 张江高科   31.28  4.44   61263346   67738236    6474890   74213126
# 恒生电子  127.13 -5.66   -7674549   68672401   76346950  145019351
# 新华保险  109.50  6.17 -122865377   42044764  164910141  206954905
# 杉杉股份   39.64  9.99   -2866847   24486796   27353643   51840439
# 永辉超市   20.77  3.32   15376747  116542950  101166203  217709153
# 海螺水泥   17.94  2.75  -46190635   55035529  101226164  156261693
# 海通证券   32.23 -4.23  -77655946   34954188  112610134  147564322
# 贵州茅台  891.01  1.72  -56396821  284161807  340558628  624720435
# 金地集团   14.48 -5.42  -23166645   10601647   33768292   44369939
# 风帆股份   99.92  5.84  -96574971   54102772  150677743  204780515

# %%
yutong = SH[SH.名称 == "宇通客车"]
yutong = yutong.sort(columns = '日期')
yutong.head()
# Out:
#       市场                          日期      代码    名称    收盘价   涨跌幅        净买额  \
# 5417  上海  2014-11-28 00:00:00.000000  600066  宇通客车  18.67 -0.37  205870534
# 5329  上海  2014-12-05 00:00:00.000000  600066  宇通客车  20.52  3.43  212824752
# 5308  上海  2014-12-08 00:00:00.000000  600066  宇通客车  21.08  2.73  125841391
# 5287  上海  2014-12-09 00:00:00.000000  600066  宇通客车  20.98 -0.47  233476417
# 5264  上海  2014-12-10 00:00:00.000000  600066  宇通客车  22.42  6.86   82719826
#
#            买入金额      卖出金额       成交金额
# 5417  206029384    158850  206188234
# 5329  230059195  17234443  247293638
# 5308  164212401  38371010  202583412
# 5287  242712234   9235817  251948051
# 5264  140461013  57741187  198202201

# %%
from IPython.display import Javascript
#runs arbitrary javascript, client-side
#out = Mytools.pdToJSON(MODS.data)

#out = yutong.to_json(orient='columns',date_unit='s')
out = yutong.to_json(orient='records', date_unit='s')
out2 = data_late.to_json(orient='columns', date_unit='s')
out10 = data_late10.to_json(orient='columns', date_unit='s')
# There should be no code after Javascript 
Javascript("""
           window.out={};
           """.format(out))

# %%
Javascript("""
           window.out2={};
           """.format(out2))

# %%
Javascript("""
           window.out10={};
           """.format(out10))

# %%
# %%html
# <div id="container" style="min-width: 310px; height: 400px; margin: 0 auto"></div>
# Out:
# <div id="container" style="min-width: 310px; height: 400px; margin: 0 auto"></div>

# %%
# %%html
# <div id="container2" style="min-width: 310px; height: 400px; margin: 0 auto"></div>
# Out:
# <div id="container2" style="min-width: 310px; height: 400px; margin: 0 auto"></div>

# %%
# %%html
# <div id="container3" style="min-width: 310px; height: 400px; margin: 0 auto"></div>
# Out:
# <div id="container3" style="min-width: 310px; height: 400px; margin: 0 auto"></div>

# %%
# %%javascript
# // out has different data order from python input
#
# var format = d3.time.format("%Y-%m-%d");
# var date = _.pluck(out,'日期');
# // alert(date);
# date = $.map(date,function (d){return d.slice(0,10)});
# // data.forEach(function (d, index, array) {plot1.push(d.Age);});
# // format.parse("2011-01-01"); // returns a Date
# //alert(date);
# var configure =  {
#
#         chart: {
#             type: 'column',
#             renderTo: 'container'
#         },
#         title: {
#             text: '宇通客车'
#         },
#         subtitle: {
#             text: '沪港通数据'
#         },
#         xAxis: {
#             categories: date,
#             crosshair: true
#         },
#         yAxis: {
#             //min: 0,
#             title: {
#                 text: '金额'
#             }
#         },
#         tooltip: {
#             headerFormat: '<span style="font-size:10px">{point.key}</span><table>',
#             pointFormat: '<tr><td style="color:{series.color};padding:0">{series.name}: </td>' +
#                 '<td style="padding:0"><b>{point.y:.1f} mm</b></td></tr>',
#             footerFormat: '</table>',
#             shared: true,
#             useHTML: true
#         },
#         plotOptions: {
#             column: {
#                 pointPadding: 0.2,
#                 borderWidth: 0
#             }
#         },
#         series: [{
#             name: '净买额',
#             data: _.pluck(out,'净买额')
#
#         }, {
#             name: '买入金额',
#             data: _.pluck(out,'买入金额')
#
#         }, {
#             name: '卖出金额',
#             data: _.pluck(out,'卖出金额')
#
#         }, {
#             name: '成交金额',
#             data: _.pluck(out,'成交金额')
#
#         }]
#     };
#
# $(function () {var chart1 = new Highcharts.chart(configure)});

# %%
# %%javascript
# // out has different data order from python input
#
# var format = d3.time.format("%Y-%m-%d");
# var name = _.keys(out2.涨跌幅);
#
# // alert(date);
# // date = $.map(date,function (d){return d.slice(0,10)});
# // data.forEach(function (d, index, array) {plot1.push(d.Age);});
# // format.parse("2011-01-01"); // returns a Date
# //alert(date);
# var configure =  {
#
#         chart: {
#             type: 'column',
#             renderTo: 'container2'
#         },
#         title: {
#             text: '最新5日'
#         },
#         subtitle: {
#             text: '沪港通数据'
#         },
#         xAxis: {
#             categories: name,
#             crosshair: true
#         },
#         yAxis: {
#             //min: 0,
#             title: {
#                 text: '金额'
#             }
#         },
#         tooltip: {
#             headerFormat: '<span style="font-size:10px">{point.key}</span><table>',
#             pointFormat: '<tr><td style="color:{series.color};padding:0">{series.name}: </td>' +
#                 '<td style="padding:0"><b>{point.y:.1f} mm</b></td></tr>',
#             footerFormat: '</table>',
#             shared: true,
#             useHTML: true
#         },
#         plotOptions: {
#             column: {
#                 pointPadding: 0.2,
#                 borderWidth: 0
#             }
#         },
#         series: [{
#             name: '净买额',
#             data: _.values(out2.净买额)
#
#         }, {
#             name: '买入金额',
#             data: _.values(out2.买入金额)
#
#         }, {
#             name: '卖出金额',
#             data: _.values(out2.卖出金额)
#
#         }, {
#             name: '成交金额',
#             data: _.values(out2.成交金额)
#
#         }]
#     };
#
# $(function () {var chart2 = new Highcharts.chart(configure)});

# %%
# %%javascript
# // out has different data order from python input
# out2 = out10
# var format = d3.time.format("%Y-%m-%d");
# var name = _.keys(out2.涨跌幅);
#
# // alert(date);
# // date = $.map(date,function (d){return d.slice(0,10)});
# // data.forEach(function (d, index, array) {plot1.push(d.Age);});
# // format.parse("2011-01-01"); // returns a Date
# //alert(date);
# var configure =  {
#
#         chart: {
#             type: 'column',
#             renderTo: 'container3'
#         },
#         title: {
#             text: '最新10日'
#         },
#         subtitle: {
#             text: '沪港通数据'
#         },
#         xAxis: {
#             categories: name,
#             crosshair: true
#         },
#         yAxis: {
#             //min: 0,
#             title: {
#                 text: '金额'
#             }
#         },
#         tooltip: {
#             headerFormat: '<span style="font-size:10px">{point.key}</span><table>',
#             pointFormat: '<tr><td style="color:{series.color};padding:0">{series.name}: </td>' +
#                 '<td style="padding:0"><b>{point.y:.1f} mm</b></td></tr>',
#             footerFormat: '</table>',
#             shared: true,
#             useHTML: true
#         },
#         plotOptions: {
#             column: {
#                 pointPadding: 0.2,
#                 borderWidth: 0
#             }
#         },
#         series: [{
#             name: '净买额',
#             data: _.values(out2.净买额)
#
#         }, {
#             name: '买入金额',
#             data: _.values(out2.买入金额)
#
#         }, {
#             name: '卖出金额',
#             data: _.values(out2.卖出金额)
#
#         }, {
#             name: '成交金额',
#             data: _.values(out2.成交金额)
#
#         }]
#     };
#
# $(function () {var chart2 = new Highcharts.chart(configure)});
